# %%
# Setting up the imports 

from steemdata import SteemData
import datetime
from datetime import datetime as dt

import numpy as np

import pandas as pd

# %%
# Init connection to database

db = SteemData()

# %%
query = {
    'type' : 'vote',
    'timestamp' : {'$gte': dt.now() - datetime.timedelta(days=1)},
    'author': 'alexeykh'}
    
proj = {'_id': 0, 'timestamp': 1, 'voter' : 1, 'weight': 1}

sort = [('timestamp', -1)]

# %%
# %%time

result = db.Operations.find(query,
                            projection=proj,
                            sort=sort)

res = list(result)
# Out:
# Wall time: 1.04 s

# %%
Data = pd.DataFrame({'voter': [e['voter'] for e in res],
                     'weight': [e['weight']/100 for e in res]},
              index=[e['timestamp'] for e in res])

# %%
len(Data)
# Out:
# 16696

# %%
VoteSort = Data.groupby('voter').sum().sort_values('weight', ascending=False)

VoteSort
# Out:
#                 weight
# voter
# aaron51         800.00
# papakmega1      800.00
# peririus        800.00
# perirgas        800.00
# perigar         800.00
# perieli         800.00
# peralphi        800.00
# pepperra        800.00
# peloelo         800.00
# pelleela        800.00
# pelar           800.00
# pavelnin        800.00
# paulpfeiffer32  800.00
# pasha0331       800.00
# param           800.00
# panolegu        800.00
# pezius          800.00
# palmar          800.00
# paletic         800.00
# paladino        800.00
# pakher          800.00
# painrunner      800.00
# paasinke        800.00
# ovatara         800.00
# osmair          800.00
# osken           800.00
# osiganie        800.00
# oriestil        800.00
# orensab         800.00
# orehovvitaliyy  800.00
# ...                ...
# sergejsoldatov  700.00
# n19serg78       700.00
# masher22        700.00
# brlera          700.00
# valentin123     700.00
# ooolgapo23      700.00
# werako4i        700.00
# ...
